# %% [markdown]
# # Paso 1 - conectarse a la API

# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.9.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=0.25 in c:\users\cecilia\anaconda3\lib\site-packages (from pytrends) (1.4.2)
# Requirement already satisfied: requests>=2.0 in c:\users\cecilia\anaconda3\lib\site-packages (from pytrends) (2.28.0)
# Requirement already satisfied: lxml in c:\users\cecilia\anaconda3\lib\site-packages (from pytrends) (4.9.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cecilia\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\cecilia\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\cecilia\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\cecilia\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cecilia\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\cecilia\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cecilia\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cecilia\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2022.6.15)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.2
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)

# %%
import json

import pandas as pd
import requests

from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from requests import status_codes

from pytrends import exceptions

from urllib.parse import quote

# %% [markdown]
# ### Web seleccionada: https://www.themoviedb.org/

# %%
url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc&year=2022"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjN2VlNDhmZTE3N2QyZTZmMDRjNjU4YmFkMGRkYmUwNSIsInN1YiI6IjY0NjE2MzA4ZTNmYTJmMDE0NWVjOTU0OSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.3fz-JoSbeOqP0E-iGxYV62VgU9GsXZXA5OX2ftcZ7V4"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/8rpDcsfLJypbO6vREc0547VKqEv.jpg","genre_ids":[878,12,28],"id":76600,"original_language":"en","original_title":"Avatar: The Way of Water","overview":"Set more than a decade after the events of the first film, learn the story of the Sully family (Jake, Neytiri, and their kids), the trouble that follows them, the lengths they go to keep each other safe, the battles they fight to stay alive, and the tragedies they endure.","popularity":1961.805,"poster_path":"/t6HIqrRAclMCA60NsSmeqe9RmNV.jpg","release_date":"2022-12-14","title":"Avatar: The Way of Water","video":false,"vote_average":7.7,"vote_count":7938},{"adult":false,"backdrop_path":"/jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg","genre_ids":[16,10751,14,12,35],"id":315162,"original_language":"en","original_title":"Puss in Boots: The Last Wish","overview":"Puss in Boots discovers that his passion for adventure has taken its toll: He has burned through eight of his nine lives, leaving him with only one life left. Puss sets out on an epic journey to find the mythical Last Wish and restore his nine lives.","popularity":945.114,"poster_path":"/kuf6dutpsT0vSVehic3EZIqkOBt.jpg","release_date":"2022-12-07","title":"Puss in Boots: The Last Wish","video":false,"vote_average":8.3,"vote_count":5491},{"adult":false,"backdrop_path":"/aRJjCgp4uVUkXhDw8NClesQXbt3.jpg","genre_ids":[53,28],"id":727340,"original_language":"ko","original_title":"헌트","overview":"After a high-ranking North Korean official requests asylum, KCIA Foreign Unit chief Park Pyong-ho and Domestic Unit chief Kim Jung-do are tasked with uncovering a North Korean spy, known as Donglim, who is deeply embedded within their agency. When the spy begins leaking top secret intel that could jeopardize national security, the two units are each assigned to investigate each other.","popularity":816.63,"poster_path":"/tDe5eLxAbeK7sYckUn5aH3ngWnn.jpg","release_date":"2022-08-10","title":"Hunt","video":false,"vote_average":6.9,"vote_count":67},{"adult":false,"backdrop_path":"/wUwFMnbFxuDfcRSGGT7QQIGDRrH.jpg","genre_ids":[27],"id":785759,"original_language":"en","original_title":"Two Witches","overview":"A matriarchal witch passes on her sinister inheritance to her grand-daughter, triggering the most horrific curses.","popularity":1119.195,"poster_path":"/uL9fFTdNmUUlKIJfHJclN5X3bxH.jpg","release_date":"2023-03-02","title":"Two Witches","video":false,"vote_average":6.1,"vote_count":42},{"adult":false,"backdrop_path":"/xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg","genre_ids":[28,12,878],"id":505642,"original_language":"en","original_title":"Black Panther: Wakanda Forever","overview":"Queen Ramonda, Shuri, M’Baku, Okoye and the Dora Milaje fight to protect their nation from intervening world powers in the wake of King T’Challa’s death.  As the Wakandans strive to embrace their next chapter, the heroes must band together with the help of War Dog Nakia and Everett Ross and forge a new path for the kingdom of Wakanda.","popularity":572.226,"poster_path":"/sv1xJUazXeYqALzczSZ3O6nkH75.jpg","release_date":"2022-11-09","title":"Black Panther: Wakanda Forever","video":false,"vote_average":7.3,"vote_count":4775},{"adult":false,"backdrop_path":"/cZzZlwGvxiByXam0lZ57J9IN233.jpg","genre_ids":[27],"id":1008005,"original_language":"es","original_title":"La niña de la comunión","overview":"Spain, late 1980s. Newcomer Sara tries to fit in with the other teens in this tight-knit small town in the province of Tarragona. If only she were more like her extroverted best friend, Rebe. They go out one night at a nightclub, on the way home, they come upon a little girl holding a doll, dressed for her first communion. And that's when the nightmare begins.","popularity":553.446,"poster_path":"/uYxrWr9o44yO0HvVfFFHGu01gfX.jpg","release_date":"2023-02-10","title":"The Communion Girl","video":false,"vote_average":6.1,"vote_count":96},{"adult":false,"backdrop_path":"/tFaC1Fb1sv1dALB0i9Avi76MHmn.jpg","genre_ids":[10751,28,12],"id":946310,"orig ...

# %% [markdown]
# # Paso 2 - Dar formato de tabla a los datos

# %%
# Convert JSON to DataFrame Using read_json()
df = pd.read_json(response.text)
df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/8rpDcsfLJy...         1953
# 1      1  {'adult': False, 'backdrop_path': '/jr8tSoJGj3...         1953
# 2      1  {'adult': False, 'backdrop_path': '/aRJjCgp4uV...         1953
# 3      1  {'adult': False, 'backdrop_path': '/wUwFMnbFxu...         1953
# 4      1  {'adult': False, 'backdrop_path': '/xDMIl84Qo5...         1953
# 5      1  {'adult': False, 'backdrop_path': '/cZzZlwGvxi...         1953
# 6      1  {'adult': False, 'backdrop_path': '/tFaC1Fb1sv...         1953
# 7      1  {'adult': False, 'backdrop_path': '/nDmPjKLqLw...         1953
# 8      1  {'adult': False, 'backdrop_path': '/bQXAqRx2Fg...         1953
# 9      1  {'adult': False, 'backdrop_path': '/eNJhWy7xFz...         1953
# 10     1  {'adult': False, 'backdrop_path': '/xmcPahH2mO...         1953
# 11     1  {'adult': False, 'backdrop_path': '/sp7MPK2K60...         1953
# 12     1  {'adult': False, 'backdrop_path': '/1PRWW60yQp...         1953
# 13     1  {'adult': False, 'backdrop_path': '/g03h9TULzJ...         1953
# 14     1  {'adult': False, 'backdrop_path': '/bKWFetR4in...         1953
# 15     1  {'adult': False, 'backdrop_path': '/dlrWhn0G3A...         1953
# 16     1  {'adult': False, 'backdrop_path': '/94TIUEhuwv...         1953
# 17     1  {'adult': False, 'backdrop_path': '/9j7EPYAaS2...         1953
# 18     1  {'adult': False, 'backdrop_path': '/zGoZB4CboM...         1953
# 19     1  {'adult': False, 'backdrop_path': '/nJbWAc8wak...         1953
#
#     total_results
# 0           39059
# 1           39059
# 2           39059
# 3           39059
# 4           39059
# 5           39059
# 6           39059
# 7           39059
# 8           39059
# 9           39059
# 10          39059
# 11          39059
# 12          39059
# 13          39059
# 14          39059
# 15          39059
# 16          39059
# 17          39059
# 18          39059
# 19          39059

# %%
x = df['results'].to_json()
x
# Out:
# '{"0":{"adult":false,"backdrop_path":"\\/8rpDcsfLJypbO6vREc0547VKqEv.jpg","genre_ids":[878,12,28],"id":76600,"original_language":"en","original_title":"Avatar: The Way of Water","overview":"Set more than a decade after the events of the first film, learn the story of the Sully family (Jake, Neytiri, and their kids), the trouble that follows them, the lengths they go to keep each other safe, the battles they fight to stay alive, and the tragedies they endure.","popularity":1961.805,"poster_path":"\\/t6HIqrRAclMCA60NsSmeqe9RmNV.jpg","release_date":"2022-12-14","title":"Avatar: The Way of Water","video":false,"vote_average":7.7,"vote_count":7938},"1":{"adult":false,"backdrop_path":"\\/jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg","genre_ids":[16,10751,14,12,35],"id":315162,"original_language":"en","original_title":"Puss in Boots: The Last Wish","overview":"Puss in Boots discovers that his passion for adventure has taken its toll: He has burned through eight of his nine lives, leaving him with only one life left. Puss sets out on an epic journey to find the mythical Last Wish and restore his nine lives.","popularity":945.114,"poster_path":"\\/kuf6dutpsT0vSVehic3EZIqkOBt.jpg","release_date":"2022-12-07","title":"Puss in Boots: The Last Wish","video":false,"vote_average":8.3,"vote_count":5491},"2":{"adult":false,"backdrop_path":"\\/aRJjCgp4uVUkXhDw8NClesQXbt3.jpg","genre_ids":[53,28],"id":727340,"original_language":"ko","original_title":"\\ud5cc\\ud2b8","overview":"After a high-ranking North Korean official requests asylum, KCIA Foreign Unit chief Park Pyong-ho and Domestic Unit chief Kim Jung-do are tasked with uncovering a North Korean spy, known as Donglim, who is deeply embedded within their agency. When the spy begins leaking top secret intel that could jeopardize national security, the two units are each assigned to investigate each other.","popularity":816.63,"poster_path":"\\/tDe5eLxAbeK7sYckUn5aH3ngWnn.jpg","release_date":"2022-08-10","title":"Hunt","video":false,"vote_average":6.9,"vote_count":67},"3":{"adult":false,"backdrop_path":"\\/wUwFMnbFxuDfcRSGGT7QQIGDRrH.jpg","genre_ids":[27],"id":785759,"original_language":"en","original_title":"Two Witches","overview":"A matriarchal witch passes on her sinister inheritance to her grand-daughter, triggering the most horrific curses.","popularity":1119.195,"poster_path":"\\/uL9fFTdNmUUlKIJfHJclN5X3bxH.jpg","release_date":"2023-03-02","title":"Two Witches","video":false,"vote_average":6.1,"vote_count":42},"4":{"adult":false,"backdrop_path":"\\/xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg","genre_ids":[28,12,878],"id":505642,"original_language":"en","original_title":"Black Panther: Wakanda Forever","overview":"Queen Ramonda, Shuri, M\\u2019Baku, Okoye and the Dora Milaje fight to protect their nation from intervening world powers in the wake of King T\\u2019Challa\\u2019s death.  As the Wakandans strive to embrace their next chapter, the heroes must band together with the help of War Dog Nakia and Everett Ross and forge a new path for the kingdom of Wakanda.","popularity":572.226,"poster_path":"\\/sv1xJUazXeYqALzczSZ3O6nkH75.jpg","release_date":"2022-11-09","title":"Black Panther: Wakanda Forever","video":false,"vote_average":7.3,"vote_count":4775},"5":{"adult":false,"backdrop_path":"\\/cZzZlwGvxiByXam0lZ57J9IN233.jpg","genre_ids":[27],"id":1008005,"original_language":"es","original_title":"La ni\\u00f1a de la comuni\\u00f3n","overview":"Spain, late 1980s. Newcomer Sara tries to fit in with the other teens in this tight-knit small town in the province of Tarragona. If only she were more like her extroverted best friend, Rebe. They go out one night at a nightclub, on the way home, they come upon a little girl holding a doll, dressed for her first communion. And that\'s when the nightmare begins.","popularity":553.446,"poster_path":"\\/uYxrWr9o44yO0HvVfFFHGu01gfX.jpg","release_date":"2023-02-10","title":"The Communion Girl","video":false,"vote_average":6.1,"vote_count":96},"6":{"adult":false,"backdrop_path":"\ ...

# %%
df2 = pd.read_json(x, orient = 'column').T
df2.head()
# Out:
#    adult                     backdrop_path                genre_ids      id  \
# 0  False  /8rpDcsfLJypbO6vREc0547VKqEv.jpg            [878, 12, 28]   76600
# 1  False  /jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg  [16, 10751, 14, 12, 35]  315162
# 2  False  /aRJjCgp4uVUkXhDw8NClesQXbt3.jpg                 [53, 28]  727340
# 3  False  /wUwFMnbFxuDfcRSGGT7QQIGDRrH.jpg                     [27]  785759
# 4  False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg            [28, 12, 878]  505642
#
#   original_language                  original_title  \
# 0                en        Avatar: The Way of Water
# 1                en    Puss in Boots: The Last Wish
# 2                ko                              헌트
# 3                en                     Two Witches
# 4                en  Black Panther: Wakanda Forever
#
#                                             overview popularity  \
# 0  Set more than a decade after the events of the...   1961.805
# 1  Puss in Boots discovers that his passion for a...    945.114
# 2  After a high-ranking North Korean official req...     816.63
# 3  A matriarchal witch passes on her sinister inh...   1119.195
# 4  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...    572.226
#
#                         poster_path release_date  \
# 0  /t6HIqrRAclMCA60NsSmeqe9RmNV.jpg   2022-12-14
# 1  /kuf6dutpsT0vSVehic3EZIqkOBt.jpg   2022-12-07
# 2  /tDe5eLxAbeK7sYckUn5aH3ngWnn.jpg   2022-08-10
# 3  /uL9fFTdNmUUlKIJfHJclN5X3bxH.jpg   2023-03-02
# 4  /sv1xJUazXeYqALzczSZ3O6nkH75.jpg   2022-11-09
#
#                             title  video vote_average vote_count
# 0        Avatar: The Way of Water  False          7.7       7938
# 1    Puss in Boots: The Last Wish  False          8.3       5491
# 2                            Hunt  False          6.9         67
# 3                     Two Witches  False          6.1         42
# 4  Black Panther: Wakanda Forever  False          7.3       4775

# %%
df3 = df2.drop(columns = ['genre_ids'])
df3.head()
# Out:
#    adult                     backdrop_path      id original_language  \
# 0  False  /8rpDcsfLJypbO6vREc0547VKqEv.jpg   76600                en
# 1  False  /jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg  315162                en
# 2  False  /aRJjCgp4uVUkXhDw8NClesQXbt3.jpg  727340                ko
# 3  False  /wUwFMnbFxuDfcRSGGT7QQIGDRrH.jpg  785759                en
# 4  False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg  505642                en
#
#                    original_title  \
# 0        Avatar: The Way of Water
# 1    Puss in Boots: The Last Wish
# 2                              헌트
# 3                     Two Witches
# 4  Black Panther: Wakanda Forever
#
#                                             overview popularity  \
# 0  Set more than a decade after the events of the...   1961.805
# 1  Puss in Boots discovers that his passion for a...    945.114
# 2  After a high-ranking North Korean official req...     816.63
# 3  A matriarchal witch passes on her sinister inh...   1119.195
# 4  Queen Ramonda, Shuri, M’Baku, Okoye and the Do...    572.226
#
#                         poster_path release_date  \
# 0  /t6HIqrRAclMCA60NsSmeqe9RmNV.jpg   2022-12-14
# 1  /kuf6dutpsT0vSVehic3EZIqkOBt.jpg   2022-12-07
# 2  /tDe5eLxAbeK7sYckUn5aH3ngWnn.jpg   2022-08-10
# 3  /uL9fFTdNmUUlKIJfHJclN5X3bxH.jpg   2023-03-02
# 4  /sv1xJUazXeYqALzczSZ3O6nkH75.jpg   2022-11-09
#
#                             title  video vote_average vote_count
# 0        Avatar: The Way of Water  False          7.7       7938
# 1    Puss in Boots: The Last Wish  False          8.3       5491
# 2                            Hunt  False          6.9         67
# 3                     Two Witches  False          6.1         42
# 4  Black Panther: Wakanda Forever  False          7.3       4775

# %% [markdown]
# # Paso 3 - Conexion a Base de datos

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.6-cp39-cp39-win_amd64.whl (1.2 MB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.6
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\cecilia\anaconda3\lib\site-packages)

# %%
import psycopg2

url="data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws"
data_base="data-engineer-database"
user="ceci_podesta_coderhouse"
with open(r"C:\Users\Cecilia\Documents\Data Eng Coder\credenciales\pwd_coder.txt",'r') as f:
    pwd= f.read()

try:
    conn = psycopg2.connect(
        host='data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws.com',
        dbname=data_base,
        user=user,
        password=pwd,
        port='5439'
    )
    print("Connected to Redshift successfully!")
    
except Exception as e:
    print("Unable to connect to Redshift.")
    print(e)
# Out:
# Connected to Redshift successfully!

# %% [markdown]
# # Paso 4: Funcion auxiliar para carga en el DW

# %%
from psycopg2.extras import execute_values

def cargar_en_redshift(conn, table_name, dataframe):
    dtypes= dataframe.dtypes
    cols= list(dtypes.index )
    tipos= list(dtypes.values)
    type_map = {'int64': 'INT','int32': 'INT','float64': 'FLOAT','object': 'VARCHAR(600)','bool':'BOOLEAN'}
    sql_dtypes = [type_map[str(dtype)] for dtype in tipos]
    # Definir formato SQL VARIABLE TIPO_DATO
    column_defs = [f"{name} {data_type}" for name, data_type in zip(cols, sql_dtypes)]
    # Combine column definitions into the CREATE TABLE statement
    table_schema = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            {', '.join(column_defs)}
        );
        """
    # Crear la tabla
    cur = conn.cursor()
    cur.execute(table_schema)
    # Generar los valores a insertar
    values = [tuple(x) for x in dataframe.to_numpy()]
    # Definir el INSERT
    insert_sql = f"INSERT INTO {table_name} ({', '.join(cols)}) VALUES %s"
    # Execute the transaction to insert the data
    cur.execute("BEGIN")
    execute_values(cur, insert_sql, values)
    cur.execute("COMMIT")
    print('Proceso terminado')

# %%
cargar_en_redshift(conn=conn, table_name='peliculas_2022', dataframe=df3)
# Out:
# Proceso terminado
